# %% [markdown]
# # Objectives
#
# - Use gold price as target variable and collect various and different factors as features to predict gold price

# %% [markdown]
# # Import

# %%
import pandas as pd
from datetime import datetime

# %% [markdown]
# # Read Data

# %% [markdown]
# ## Gold Price Data
# 1. Download gold price data from https://www.gold.org/goldhub/data/gold-prices in `xlsx` format
# 2. Select monthly avergage gold price data in USD and save as **`PRICE-MONTHLY.csv`**

# %%
price = pd.read_csv('PRICE-MONTHLY.csv', parse_dates=['DATE'])

# create YearMonth column to easily merge data
price['YearMonth'] = price['DATE'].map(lambda x: 100*x.year + x.month)
price.head()
# Out:
#         DATE  PRICE  YearMonth
# 0 1978-12-31  207.8     197812
# 1 1979-01-31  227.3     197901
# 2 1979-02-28  245.7     197902
# 3 1979-03-30  242.1     197903
# 4 1979-04-30  239.2     197904

# %%
# quick check the null values
price.isnull().sum()
# Out:
# DATE         0
# PRICE        0
# YearMonth    0
# dtype: int64

# %%
# quick check the strat and end date of data
display(price['DATE'].min())
price['DATE'].max()
# Out:
# Timestamp('1978-12-31 00:00:00')
# Timestamp('2019-09-30 00:00:00')

# %% [markdown]
# ## Nominal Effective Exchange Rate Data
# 1. Download nominal effective exchange rate data from https://www.bis.org/statistics/eer.htm in `csv` format
# 2. Select daily US nominal effective exchange monthly and save as **`NEER.csv`**

# %%
neer = pd.read_csv('NEER.csv',parse_dates=['DATE'])

# transform daily neer data to monthly data
neer_monthly = neer.resample('M', on='DATE').mean().reset_index()

# create YearMonth column to easily merge data
neer_monthly['YearMonth'] = neer_monthly['DATE'].map(lambda x: 100*x.year + x.month)
neer_monthly.head()
# Out:
#         DATE        NEER  YearMonth
# 0 1983-10-31  152.060952     198310
# 1 1983-11-30  153.582273     198311
# 2 1983-12-31  155.408636     198312
# 3 1984-01-31  156.589545     198401
# 4 1984-02-29  154.926667     198402

# %%
# quick check the null values
neer_monthly.isnull().sum()
# Out:
# DATE         0
# NEER         0
# YearMonth    0
# dtype: int64

# %%
# quick check the strat and end date of data
display(neer['DATE'].min())
neer['DATE'].max()
# Out:
# Timestamp('1983-10-03 00:00:00')
# Timestamp('2019-09-30 00:00:00')

# %% [markdown]
# ## Effective Federal Funds Rate Data
# 1. Download monthly effective federal funds rate data from https://fred.stlouisfed.org/series/FEDFUNDS and save as **`FFR-MONTHLY.csv`**

# %%
ffr = pd.read_csv('FFR-MONTHLY.csv', parse_dates=['DATE'])
# create YearMonth column to easily merge data
ffr['YearMonth'] = ffr['DATE'].map(lambda x: 100*x.year + x.month)
ffr.head()
# Out:
#         DATE  FEDFUNDS  YearMonth
# 0 1954-07-01      0.80     195407
# 1 1954-08-01      1.22     195408
# 2 1954-09-01      1.06     195409
# 3 1954-10-01      0.85     195410
# 4 1954-11-01      0.83     195411

# %%
# quick check the null values
ffr.isnull().sum()
# Out:
# DATE         0
# FEDFUNDS     0
# YearMonth    0
# dtype: int64

# %%
# quick check the strat and end date of data
display(ffr['DATE'].min())
ffr['DATE'].max()
# Out:
# Timestamp('1954-07-01 00:00:00')
# Timestamp('2019-09-01 00:00:00')

# %% [markdown]
# ## Consumer Price Index Data
# 1. Download consumer price index data from https://fred.stlouisfed.org/series/CPIAUCSL and save as **`CPI-MONTHLY.csv`**

# %%
cpi = pd.read_csv('CPI-MONTHLY.csv', parse_dates=['DATE'])
# create YearMonth column to easily merge data
cpi['YearMonth'] = cpi['DATE'].map(lambda x: 100*x.year + x.month)
cpi.head()
# Out:
#         DATE  CPIHOSNS  YearMonth
# 0 1967-01-01      30.5     196701
# 1 1967-02-01      30.5     196702
# 2 1967-03-01      30.5     196703
# 3 1967-04-01      30.6     196704
# 4 1967-05-01      30.7     196705

# %%
# quick check the null values
cpi.isnull().sum()
# Out:
# DATE         0
# CPIHOSNS     0
# YearMonth    0
# dtype: int64

# %%
# quick check the strat and end date of data
display(cpi['DATE'].min())
cpi['DATE'].max()
# Out:
# Timestamp('1967-01-01 00:00:00')
# Timestamp('2019-08-01 00:00:00')

# %% [markdown]
# ## Dow Jones Industrial Average Data
# 1. Download Dow Jones industrial average data from https://finance.yahoo.com/quote/%5EDJI/history?p=%5EDJI and save as **`DJIA-MONTHLY.csv`**

# %%
djia = pd.read_csv('DJIA-MONTHLY.csv', parse_dates=['Date'])
# create YearMonth column to easily merge data
djia['YearMonth'] = dfi['Date'].map(lambda x: 100*x.year + x.month)
djia.head()
# Out:
#         Date         Open         High          Low        Close    Adj Close  \
# 0 1985-01-01  1277.719971  1305.099976  1266.890015  1286.770020  1286.770020
# 1 1985-02-01  1276.939941  1307.530029  1263.910034  1284.010010  1284.010010
# 2 1985-03-01  1285.339966  1309.959961  1242.819946  1266.780029  1266.780029
# 3 1985-04-01  1264.800049  1290.300049  1245.800049  1258.060059  1258.060059
# 4 1985-05-01  1257.180054  1320.790039  1235.530029  1315.410034  1315.410034
#
#       Volume  YearMonth
# 0   44450000     198501
# 1  207300000     198502
# 2  201050000     198503
# 3  187110000     198504
# 4  242250000     198505

# %%
# quick check the null values
djia.isnull().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# YearMonth    0
# dtype: int64

# %%
# quick check the strat and end date of data
display(djia['Date'].min())
djia['Date'].max()
# Out:
# Timestamp('1985-01-01 00:00:00')
# Timestamp('2019-10-01 00:00:00')

# %% [markdown]
# ## World Offical Gold Reserve Data
# 1. Download world offical gold reserve data from https://www.gold.org/goldhub/data/monthly-central-bank-statistics in `xlsx` format
# 2. Select quarterly wold gold reserve in toones and save as **`WGR-QUARTERLY.csv`**

# %%
wgr = pd.read_csv('WGR-QUARTERLY.csv', parse_dates=['DATE'])
wgr.head()
# Out:
#       DATE  VOLUME
# 0  Q1 2000  33,444
# 1  Q2 2000  33,267
# 2  Q3 2000  33,310
# 3  Q4 2000  33,212
# 4  Q1 2001  33,065

# %%
# quick check the null values
wgr.isnull().sum()
# Out:
# DATE      0
# VOLUME    0
# dtype: int64

# %%
# quick check the strat and end date of data
display(wgr['DATE'].min())
wgr['DATE'].max()
# Out:
# 'Q1 2000'
# 'Q4 2018'

# %%
# merge 5 datasets except world offical gold reserve dataset
final_merge = price.merge(neer_monthly,how='inner',on='YearMonth').merge(ffr, how='inner', on='YearMonth').merge(cpi, how='inner', on='YearMonth').merge(djia, how='inner', on='YearMonth')

# %%
# drop duplicated columns
final_drop = final_merge.drop(columns=['DATE_y', 'DATE_x'])
final_drop.columns
# Out:
# Index(['PRICE', 'YearMonth', 'NEER', 'FEDFUNDS', 'CPIHOSNS', 'Date', 'Open',
#        'High', 'Low', 'Close', 'Adj Close', 'Volume'],
#       dtype='object')

# %%
# rename columns
final_drop.columns = ['gold_price', 'year_month','nominal_effective_exchange_rate',' effective_federal_funds_rate','cpi_index','date','djia_open','djia_high',
                     'djia_low','djia_close','djia_adj_close','djia_volume']

final = final_drop.set_index('date').reset_index()
final
# Out:
#           date gold_price  year_month  nominal_effective_exchange_rate  \
# 0   1985-01-01      302.8      198501                       171.491304
# 1   1985-02-01      299.1      198502                       176.187000
# 2   1985-03-01      303.9      198503                       177.040476
# 3   1985-04-01      325.3      198504                       170.949545
# 4   1985-05-01      316.4      198505                       171.393913
# 5   1985-06-01      316.5      198506                       169.692500
# 6   1985-07-01      317.2      198507                       164.653478
# 7   1985-08-01      329.8      198508                       162.478182
# 8   1985-09-01      323.4      198509                       163.872857
# 9   1985-10-01      325.8      198510                       156.121304
# 10  1985-11-01      325.3      198511                       153.444286
# 11  1985-12-01      321.9      198512                       152.637727
# 12  1986-01-01      345.4      198601                       151.536087
# 13  1986-02-01      338.9      198602                       146.601500
# 14  1986-03-01      345.7      198603                       143.957619
# 15  1986-04-01      340.4      198604                       142.801364
# 16  1986-05-01      342.4      198605                       139.953636
# 17  1986-06-01      342.7      198606                       140.780952
# 18  1986-07-01      348.3      198607                       137.523913
# 19  1986-08-01      376.6      198608                       135.421429
# 20  1986-09-01      417.7      198609                       135.217273
# 21  1986-10-01      423.5      198610                       135.261304
# 22  1986-11-01      397.6      198611                       137.057000
# 23  1986-12-01      390.9      198612                       135.937826
# 24  1987-01-01      408.3      198701                       131.047727
# 25  1987-02-01      401.1      198702                       129.241000
# 26  1987-03-01      408.9      198703                       127.896364
# 27  1987-04-01      438.4      198704                       124.995455
# 28  1987-05-01      460.2      198705                       123.840000
# 29  1987-06-01      449.6      198706                       125.109091
# ..         ...        ...         ...                              ...
# 386 2017-03-01   1,231.10      201703                       121.345652
# 387 2017-04-01   1,265.60      201704                       120.646500
# 388 2017-05-01   1,245.00      201705                       119.707826
# 389 2017-06-01   1,260.30      201706                       118.226364
# 390 2017-07-01   1,236.20      201707                       115.971429
# 391 2017-08-01   1,282.30      201708                       114.226522
# 392 2017-09-01   1,315.00      201709                       113.030476
# 393 2017-10-01   1,279.50      201710                       114.796818
# 394 2017-11-01   1,282.30      201711                       115.022273
# 395 2017-12-01   1,261.30      201712                       114.406667
# 396 2018-01-01   1,331.70      201801                       111.575217
# 397 2018-02-01   1,331.50      201802                       110.796500
# 398 2018-03-01   1,324.70      201803                       111.302273
# 399 2018-04-01   1,334.70      201804                       111.415714
# 400 2018-05-01   1,303.00      201805                       114.194348
# 401 2018-06-01   1,281.60      201806                       115.563333
# 402 2018-07-01   1,238.50      201807                       116.234091
# 403 2018-08-01   1,201.30      201808                       116.681304
# 404 2018-09-01   1,198.50      201809                       116.264500
# 405 2018-10-01   1,215.40      201810                       117.229565
# 406 2018-11-01   1,221.00      201811                       118.107273
# 407 2018-12-01   1,247.90      201812                       118.441905
# 408 2019-01-01   1,291.80      201901                       117.455217
# 409 2019-02-01   1,320.10      201902                       117.676500
# 410 2019-03-01   1,300.90      201903                       118.305238
# 411 2019-04-01   1,286.40      201904                       118.825000
# 412 2019-05-01   1,284.00      201905                       119.594783
# 413 2019-06-01   1,359.00      201906                       118.444000
