# %% [markdown]
# # Set Up

# %% [markdown]
# ## Import

# %%
import pandas as pd
import datetime as dt
pd.options.display.max_columns=999

# %% [markdown]
# ## Read Data

# %%
price = pd.read_csv('us_equity_daily_price_201308_201908.csv', parse_dates=['date'])

# %%
price.head()
# Out:
#         date   entity_figi ticker       open       high        low      close  \
# 0 2013-08-01  BBG000C2M952   AAON  14.480000  15.100000  14.360000  15.006667
# 1 2013-08-02  BBG000C2M952   AAON  14.966666  15.320000  14.966666  15.260000
# 2 2013-08-05  BBG000C2M952   AAON  15.280000  15.473333  15.033334  15.446667
# 3 2013-08-06  BBG000C2M952   AAON  15.446667  15.466666  15.320000  15.333333
# 4 2013-08-07  BBG000C2M952   AAON  15.333333  15.520000  15.300000  15.466666
#
#      volume
# 0  353700.0
# 1  235800.0
# 2   90300.0
# 3  304800.0
# 4  128400.0

# %% [markdown]
# # Data Quality Check

# %% [markdown]
# ## Check Nan Values

# %%
# Sort values
new_price = price.sort_values(["ticker", "date"]).reset_index(drop=True).copy()
# Count nan
new_price.isnull().sum()
# Out:
# date             0
# entity_figi      0
# ticker           0
# open           488
# high           488
# low            488
# close          488
# volume         488
# dtype: int64

# %%
new_price["next_date"] = new_price.groupby("ticker")["date"].shift(-1)
new_price.head(10)
# Out:
#         date   entity_figi ticker       open       high        low      close  \
# 0 2013-08-01  BBG000C2V541      A  32.553650  33.047211  32.417740  32.932762
# 1 2013-08-02  BBG000C2V541      A  32.947067  33.268955  32.896996  33.175964
# 2 2013-08-05  BBG000C2V541      A  33.090130  33.190273  32.761086  32.861229
# 3 2013-08-06  BBG000C2V541      A  32.854076  33.061516  32.625179  32.961372
# 4 2013-08-07  BBG000C2V541      A  32.818314  33.233189  32.632332  33.104435
# 5 2013-08-08  BBG000C2V541      A  33.261803  33.297569  32.646637  32.796852
# 6 2013-08-09  BBG000C2V541      A  32.796852  33.233189  32.768242  33.061516
# 7 2013-08-12  BBG000C2V541      A  32.825466  33.268955  32.703861  33.226036
# 8 2013-08-13  BBG000C2V541      A  33.226036  33.605148  33.075821  33.562233
# 9 2013-08-14  BBG000C2V541      A  33.454937  33.619457  33.168812  33.268955
#
#       volume  next_date
# 0  3827000.0 2013-08-02
# 1  3354000.0 2013-08-05
# 2  2621800.0 2013-08-06
# 3  3188600.0 2013-08-07
# 4  2379500.0 2013-08-08
# 5  2379900.0 2013-08-09
# 6  2737800.0 2013-08-12
# 7  1743500.0 2013-08-13
# 8  2905300.0 2013-08-14
# 9  2778500.0 2013-08-15

# %%
# Show dates of missing data
new_price[new_price.open.isna()].date.unique()
# Out:
# array(['2019-08-16T00:00:00.000000000', '2018-11-06T00:00:00.000000000'],
#       dtype='datetime64[ns]')

# %%
new_price[(new_price.open.isna()) & (new_price.date=='2018-11-06T00:00:00.000000000')].index
# Out:
# Int64Index([4237695], dtype='int64')

# %%
new_price[(new_price.open.isna()) & (new_price.date=='2019-08-16T00:00:00.000000000')].count()
# Out:
# date           487
# entity_figi    487
# ticker         487
# open             0
# high             0
# low              0
# close            0
# volume           0
# next_date        0
# dtype: int64

# %%
"""
We get 487 2019-08-16 missing data witch is reasonable. 
All we need is to fill the missing data on 2018-11-06 
"""
new_price.loc[4237695, 'open'] = 3.31
new_price.loc[4237695, 'high'] = 3.46
new_price.loc[4237695, 'low'] = 3.30
new_price.loc[4237695, 'close'] = 3.39
new_price.loc[4237695, 'volume'] = 1486000

# %%
new_price.isnull().sum()
# Out:
# date              0
# entity_figi       0
# ticker            0
# open            487
# high            487
# low             487
# close           487
# volume          487
# next_date      4950
# dtype: int64

# %% [markdown]
# ## Check Date Gaps

# %%
new_price['gap'] = new_price['next_date'] - new_price['date']
new_price['gap'] = new_price['gap'].dt.days
new_price[new_price['gap'] > 3].head()
# Out:
#           date   entity_figi ticker       open       high        low  \
# 21  2013-08-30  BBG000C2V541      A  33.540771  33.605148  33.168812
# 117 2014-01-17  BBG000C2V541      A  43.512161  43.512161  43.154507
# 136 2014-02-14  BBG000C2V541      A  40.879829  41.323318  39.248928
# 179 2014-04-17  BBG000C2V541      A  38.440628  39.263233  38.347641
# 204 2014-05-23  BBG000C2V541      A  39.806866  40.214592  39.470673
#
#          close      volume  next_date  gap
# 21   33.361946   1899300.0 2013-09-03  4.0
# 117  43.426323   2375900.0 2014-01-21  4.0
# 136  39.520744  24946800.0 2014-02-18  4.0
# 179  39.091560   2882600.0 2014-04-21  4.0
# 204  40.185982   4907800.0 2014-05-27  4.0

# %%
# Show all information about the company which's gap larger than 3
new_price_gap_larger_3 = new_price[new_price['gap'] > 3].copy().reset_index(drop=True)
new_price_gap_larger_3.dropna(inplace=True)
new_price_gap_larger_3.head()
# Out:
#         date   entity_figi ticker       open       high        low      close  \
# 0 2013-08-30  BBG000C2V541      A  33.540771  33.605148  33.168812  33.361946
# 1 2014-01-17  BBG000C2V541      A  43.512161  43.512161  43.154507  43.426323
# 2 2014-02-14  BBG000C2V541      A  40.879829  41.323318  39.248928  39.520744
# 3 2014-04-17  BBG000C2V541      A  38.440628  39.263233  38.347641  39.091560
# 4 2014-05-23  BBG000C2V541      A  39.806866  40.214592  39.470673  40.185982
#
#        volume  next_date  gap
# 0   1899300.0 2013-09-03  4.0
# 1   2375900.0 2014-01-21  4.0
# 2  24946800.0 2014-02-18  4.0
# 3   2882600.0 2014-04-21  4.0
# 4   4907800.0 2014-05-27  4.0

# %%
# Show the maximum gap days 
max_gap = new_price_gap_larger_3.pivot_table(index='ticker', values='gap', aggfunc=max).reset_index()
max_gap.head()
# Out:
#   ticker   gap
# 0      A   4.0
# 1   AAAP   7.0
# 2    AAC  17.0
# 3    AAL   4.0
# 4   AAME   4.0

# %%
# Show the largest gap value
new_price_gap_larger_3["gap"].describe()
# Out:
# count    158098.000000
# mean          4.236031
# std           7.495400
# min           4.000000
# 25%           4.000000
# 50%           4.000000
# 75%           4.000000
# max         783.000000
# Name: gap, dtype: float64

# %% [markdown]
# # Data Transformation

# %%
#arrays=[list(new_price.ticker),list(range(5755898))]
#tuples=list(zip(*arrays))
#index = pd.MultiIndex.from_tuples(tuples, names=['ticker', 'ID'])
#index
#new_price_new=new_price.set_index(index)

# %%
for i in range(1,6):
    new_price[f'{i}d_prior_open'] = pd.Series(new_price.groupby("ticker")["open"].shift(i))
    new_price[f'{i}d_prior_high'] = pd.Series(new_price.groupby("ticker")["high"].shift(i))
    new_price[f'{i}d_prior_low'] = pd.Series(new_price.groupby("ticker")["low"].shift(i))
    new_price[f'{i}d_prior_close'] = pd.Series(new_price.groupby("ticker")["close"].shift(i))
    new_price[f'{i}d_prior_volume'] = pd.Series(new_price.groupby("ticker")["volume"].shift(i))
    
    new_price[f'{i}d_future_open'] = pd.Series(new_price.groupby("ticker")["open"].shift(-i))
    new_price[f'{i}d_future_high'] = pd.Series(new_price.groupby("ticker")["high"].shift(-i))
    new_price[f'{i}d_future_low'] = pd.Series(new_price.groupby("ticker")["low"].shift(-i))
    new_price[f'{i}d_future_close'] = pd.Series(new_price.groupby("ticker")["close"].shift(-i))
    new_price[f'{i}d_future_volume'] = pd.Series(new_price.groupby("ticker")["volume"].shift(-i))

# %%
new_price.head(10)
# Out:
#         date   entity_figi ticker       open       high        low      close  \
# 0 2013-08-01  BBG000C2V541      A  32.553650  33.047211  32.417740  32.932762
# 1 2013-08-02  BBG000C2V541      A  32.947067  33.268955  32.896996  33.175964
# 2 2013-08-05  BBG000C2V541      A  33.090130  33.190273  32.761086  32.861229
# 3 2013-08-06  BBG000C2V541      A  32.854076  33.061516  32.625179  32.961372
# 4 2013-08-07  BBG000C2V541      A  32.818314  33.233189  32.632332  33.104435
# 5 2013-08-08  BBG000C2V541      A  33.261803  33.297569  32.646637  32.796852
# 6 2013-08-09  BBG000C2V541      A  32.796852  33.233189  32.768242  33.061516
# 7 2013-08-12  BBG000C2V541      A  32.825466  33.268955  32.703861  33.226036
# 8 2013-08-13  BBG000C2V541      A  33.226036  33.605148  33.075821  33.562233
# 9 2013-08-14  BBG000C2V541      A  33.454937  33.619457  33.168812  33.268955
#
#       volume  next_date  gap  1d_prior_open  1d_prior_high  1d_prior_low  \
# 0  3827000.0 2013-08-02  1.0            NaN            NaN           NaN
# 1  3354000.0 2013-08-05  3.0      32.553650      33.047211     32.417740
# 2  2621800.0 2013-08-06  1.0      32.947067      33.268955     32.896996
# 3  3188600.0 2013-08-07  1.0      33.090130      33.190273     32.761086
# 4  2379500.0 2013-08-08  1.0      32.854076      33.061516     32.625179
# 5  2379900.0 2013-08-09  1.0      32.818314      33.233189     32.632332
# 6  2737800.0 2013-08-12  3.0      33.261803      33.297569     32.646637
# 7  1743500.0 2013-08-13  1.0      32.796852      33.233189     32.768242
# 8  2905300.0 2013-08-14  1.0      32.825466      33.268955     32.703861
# 9  2778500.0 2013-08-15  1.0      33.226036      33.605148     33.075821
#
#    1d_prior_close  1d_prior_volume  1d_future_open  1d_future_high  \
# 0             NaN              NaN       32.947067       33.268955
# 1       32.932762        3827000.0       33.090130       33.190273
# 2       33.175964        3354000.0       32.854076       33.061516
# 3       32.861229        2621800.0       32.818314       33.233189
# 4       32.961372        3188600.0       33.261803       33.297569
# 5       33.104435        2379500.0       32.796852       33.233189
# 6       32.796852        2379900.0       32.825466       33.268955
# 2      32.646637        32.796852         2379900.0            NaN
# 3      32.768242        33.061516         2737800.0            NaN
# 4      32.703861        33.226036         1743500.0      32.553650
# 5      33.075821        33.562233         2905300.0      32.947067
# 6      33.168812        33.268955         2778500.0      33.090130
# 7      33.512161        33.590843         9378200.0      32.854076
# 8      33.276108        33.469242         5067300.0      32.818314
# 9      33.204578        33.218884         2415100.0      33.261803
#
#    4d_prior_high  4d_prior_low  4d_prior_close  4d_prior_volume  \
# 0            NaN           NaN             NaN              NaN
# 1            NaN           NaN             NaN              NaN
# 2            NaN           NaN             NaN              NaN
# 3            NaN           NaN             NaN              NaN
# 4      33.047211     32.417740       32.932762        3827000.0
# 5      33.268955     32.896996       33.175964        3354000.0
# 6      33.190273     32.761086       32.861229        2621800.0
# 7      33.061516     32.625179       32.961372        3188600.0
# 8      33.233189     32.632332       33.104435        2379500.0
# 9      33.297569     32.646637       32.796852        2379900.0
#
#    4d_future_open  4d_future_high  4d_future_low  4d_future_close  \
# 0       32.818314       33.233189      32.632332        33.104435
# 1       33.261803       33.297569      32.646637        32.796852
# 2       32.796852       33.233189      32.768242        33.061516
# 3       32.825466       33.268955      32.703861        33.226036
# 4       33.226036       33.605148      33.075821        33.562233
# 5       33.454937       33.619457      33.168812        33.268955
# 6       34.041489       34.456367      33.512161        33.590843
# 7       33.483547       33.776825      33.276108        33.469242
# 8       33.354794       33.576538      33.204578        33.218884
# 9       33.211731       33.812588      33.025749        33.640915
#
#    4d_future_volume  5d_prior_open  5d_prior_high  5d_prior_low  \
# 0         2379500.0            NaN            NaN           NaN
# 1         2379900.0            NaN            NaN           NaN
# 2         2737800.0            NaN            NaN           NaN
# 3         1743500.0            NaN            NaN           NaN
# 4         2905300.0            NaN            NaN           NaN
# 5         2778500.0      32.553650      33.047211     32.417740
# 6         9378200.0      32.947067      33.268955     32.896996
# 7         5067300.0      33.090130      33.190273     32.761086
# 8         2415100.0      32.854076      33.061516     32.625179
# 9         3207400.0      32.818314      33.233189     32.632332
#
#    5d_prior_close  5d_prior_volume  5d_future_open  5d_future_high  \
# 0             NaN              NaN       33.261803       33.297569
# 1             NaN              NaN       32.796852       33.233189
# 2             NaN              NaN       32.825466       33.268955
# 3             NaN              NaN       33.226036       33.605148
# 4             NaN              NaN       33.454937       33.619457
# 5       32.932762        3827000.0       34.041489       34.456367
# 6       33.175964        3354000.0       33.483547       33.776825
# 7       32.861229        2621800.0       33.354794       33.576538
# 8       32.961372        3188600.0       33.211731       33.812588
# 9       33.104435        2379500.0       33.569386       33.791130
#
#    5d_future_low  5d_future_close  5d_future_volume
# 0      32.646637        32.796852         2379900.0
# 1      32.768242        33.061516         2737800.0
# 2      32.703861        33.226036         1743500.0
# 3      33.075821        33.562233         2905300.0
# 4      33.168812        33.268955         2778500.0
# 5      33.512161        33.590843         9378200.0
# 6      33.276108        33.469242         5067300.0
# 7      33.204578        33.218884         2415100.0
# 8      33.025749        33.640915         3207400.0
# 9      33.361946        33.540771         2724800.0

# %%
new_price.to_csv("finished_us_equity_daily_price_201308_201908.csv", index=False)
