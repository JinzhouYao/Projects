# %% [markdown]
# # Set Up

# %% [markdown]
# ## Import

# %%
import pandas as pd

# %% [markdown]
# ## Read In Price Data

# %%
daily_price = pd.read_csv('us_equity_daily_price_201308_201908.csv', parse_dates=['date'])
daily_price = daily_price.sort_values(['ticker', 'date']).reset_index(drop=True)

# %%
daily_price.head()
# Out:
#         date   entity_figi ticker       open       high        low      close  \
# 0 2013-08-01  BBG000C2V541      A  32.553650  33.047211  32.417740  32.932762
# 1 2013-08-02  BBG000C2V541      A  32.947067  33.268955  32.896996  33.175964
# 2 2013-08-05  BBG000C2V541      A  33.090130  33.190273  32.761086  32.861229
# 3 2013-08-06  BBG000C2V541      A  32.854076  33.061516  32.625179  32.961372
# 4 2013-08-07  BBG000C2V541      A  32.818314  33.233189  32.632332  33.104435
#
#       volume
# 0  3827000.0
# 1  3354000.0
# 2  2621800.0
# 3  3188600.0
# 4  2379500.0

# %% [markdown]
# ## Data Quality Check
# - There are no data for the current date (2019-08-16). **So we removed all the records of that date.**
# - The data of ticker `PX` on `2018-11-06` is missing, **So we manual filled the value in the CSV file.**
# - There are cases that one ticker has 2 `entity_figi`, however, the price data of two entity_figi of a given ticker are the same. **So we only kept the first entity_figi.**
# - There are 10 tickers only have one record in total. **So we removed those 10 tickers.**
# - There are 197 tickers having the date_gap > 4 days. **So we removed these tickers.**

# %%
# Check the null values
daily_price.isnull().sum()
# Out:
# date             0
# entity_figi      0
# ticker           0
# open           488
# high           488
# low            488
# close          488
# volume         488
# dtype: int64

# %%
# After Check we can find that the null values are all the price of today (2019-08-16) and 2018-11-06
"""
The null value of today is reasonable because it may haven't generate today's price data
But the null value of 2018-11-06 is unreasonable so we need to do the check in the next step
"""
daily_price[daily_price.open.isnull()].date.unique()
# Out:
# array(['2019-08-16T00:00:00.000000000', '2018-11-06T00:00:00.000000000'],
#       dtype='datetime64[ns]')

# %%
daily_price[(daily_price.date == '2018-11-06T00:00:00.000000000') & (daily_price.open.isnull())]
# Out:
#               date   entity_figi ticker  open  high  low  close  volume
# 4237695 2018-11-06  BBG000CGQ975     PX   NaN   NaN  NaN    NaN     NaN

# %%
# Fill up the missing price data of 2018-11-06
daily_price.loc[4237695, "open"] = 3.31
daily_price.loc[4237695, "high"] = 3.46
daily_price.loc[4237695, "low"] = 3.30
daily_price.loc[4237695, "close"] = 3.39
daily_price.loc[4237695, "volume"] = 1486000

# %%
# Drop the other null values
daily_price.dropna(subset=['open', 'high', 'low', 'close', 'volume'], how='all', inplace=True)

# %%
# Check if the entity_figi and the ticker are corresponding
ticker_figi = daily_price.groupby("ticker").nunique()["entity_figi"].reset_index().sort_values("entity_figi", ascending=False)

# %%
# Some of the tickers have not only one corresponding entity_figi (19 in total)
ticker_figi[ticker_figi.entity_figi != 1].head(10)
# Out:
#      ticker  entity_figi
# 2122   HRZN            2
# 1502   ESRT            2
# 1135   CXSE            2
# 2102    HOV            2
# 4379   TMUS            2
# 1764   FSAM            2
# 1099   CUBI            2
# 350     ATO            2
# 3452    PFG            2
# 420     BAC            2

# %%
# Only remain one entity_figi of each ticker
price = daily_price.drop_duplicates(subset=['ticker', 'date'], keep='first')
ticker_figi = price.groupby("ticker").nunique()["entity_figi"].reset_index().sort_values("entity_figi", ascending=False)
ticker_figi[ticker_figi.entity_figi != 1].head(10)
# Out:
#      ticker  entity_figi
# 1009   CPTA            2
# 350     ATO            2
# 1764   FSAM            2
# 3452    PFG            2
# 2501   KCAP            2
# 3937    SCS            2
# 1502   ESRT            2
# 4095   SOCL            2
# 2122   HRZN            2
# 60     ACWI            2

# %%
df = price[price.ticker == 'CPTA']
df.set_index()
# Out:
#               date   entity_figi ticker       open       high        low  \
# 1185590 2013-09-25  BBG004MYLJ43   CPTA  19.150000  19.309999  18.410000
# 1185592 2013-09-26  BBG004MYLJ43   CPTA  19.000000  19.200001  18.860001
# 1185594 2013-09-27  BBG004MYLJ43   CPTA  19.000000  19.200001  18.799999
# 1185596 2013-09-30  BBG004MYLJ43   CPTA  19.320000  19.320000  18.750000
# 1185598 2013-10-01  BBG004MYLJ43   CPTA  18.850000  19.190001  18.750000
# 1185600 2013-10-02  BBG004MYLJ43   CPTA  18.850000  18.950001  18.540001
# 1185602 2013-10-03  BBG004MYLJ43   CPTA  18.809999  18.879999  17.910000
# 1185604 2013-10-04  BBG004MYLJ43   CPTA  18.750000  18.750000  17.950001
# 1185606 2013-10-07  BBG004MYLJ43   CPTA  18.059999  18.540001  18.010000
# 1185608 2013-10-08  BBG004MYLJ43   CPTA  18.750000  18.750000  18.280001
# 1185610 2013-10-09  BBG004MYLJ43   CPTA  18.600000  18.700001  18.350000
# 1185612 2013-10-10  BBG004MYLJ43   CPTA  18.600000  18.840000  18.450001
# 1185614 2013-10-11  BBG004MYLJ43   CPTA  18.299999  18.700001  18.290001
# 1185616 2013-10-14  BBG004MYLJ43   CPTA  18.299999  18.530001  18.080000
# 1185618 2013-10-15  BBG004MYLJ43   CPTA  18.490000  18.650000  18.049999
# 1185620 2013-10-16  BBG004MYLJ43   CPTA  18.250000  18.900000  18.049999
# 1185622 2013-10-17  BBG004MYLJ43   CPTA  18.500000  18.900000  18.500000
# 1185624 2013-10-18  BBG004MYLJ43   CPTA  18.500000  19.250000  18.490000
# 1185626 2013-10-21  BBG004MYLHL8   CPTA  18.700001  19.389999  18.700001
# 1185628 2013-10-22  BBG004MYLHL8   CPTA  19.000000  19.180000  18.750000
# 1185630 2013-10-23  BBG004MYLHL8   CPTA  19.270000  19.400000  18.930000
# 1185632 2013-10-24  BBG004MYLHL8   CPTA  19.010000  19.490000  19.010000
# 1185634 2013-10-25  BBG004MYLHL8   CPTA  19.139999  19.400000  19.139999
# 1185636 2013-10-28  BBG004MYLHL8   CPTA  19.440001  20.000000  19.299999
# 1185638 2013-10-29  BBG004MYLHL8   CPTA  19.480000  19.700001  19.420000
# 1185640 2013-10-30  BBG004MYLHL8   CPTA  19.389999  19.709999  18.900000
# 1185642 2013-10-31  BBG004MYLHL8   CPTA  19.129999  19.170000  18.850000
# 1185644 2013-11-01  BBG004MYLHL8   CPTA  18.870001  19.410000  18.860001
# 1185646 2013-11-04  BBG004MYLHL8   CPTA  19.930000  19.930000  18.950001
# 1185648 2013-11-05  BBG004MYLHL8   CPTA  19.350000  19.350000  18.950001
# ...            ...           ...    ...        ...        ...        ...
# 1187876 2018-04-11  BBG004MYLJ43   CPTA   7.870000   7.930000   7.790000
# 1187878 2018-04-12  BBG004MYLJ43   CPTA   7.860000   7.869000   7.800000
# 1187880 2018-04-13  BBG004MYLJ43   CPTA   7.800000   7.870000   7.800000
# 1187882 2018-04-16  BBG004MYLJ43   CPTA   7.820000   7.989000   7.820000
# 1187884 2018-04-17  BBG004MYLJ43   CPTA   8.000000   8.110000   7.910000
# 1187886 2018-04-18  BBG004MYLJ43   CPTA   8.020000   8.030000   7.950000
# 1187888 2018-04-19  BBG004MYLJ43   CPTA   7.950000   8.060000   7.950000
# 1187890 2018-04-20  BBG004MYLJ43   CPTA   8.020000   8.050000   7.900000
# 1187892 2018-04-23  BBG004MYLJ43   CPTA   7.920000   7.990000   7.850000
# 1187894 2018-04-24  BBG004MYLJ43   CPTA   7.970000   8.030000   7.950000
# 1187896 2018-04-25  BBG004MYLJ43   CPTA   7.960000   7.990000   7.900000
# 1187898 2018-04-26  BBG004MYLJ43   CPTA   7.950000   7.990000   7.949000
# 1187900 2018-04-27  BBG004MYLJ43   CPTA   7.990000   8.020000   7.920000
# 1187902 2018-04-30  BBG004MYLJ43   CPTA   7.970000   8.025000   7.950000
# 1187904 2018-05-01  BBG004MYLJ43   CPTA   7.990000   7.990000   7.940000
# 1187906 2018-05-02  BBG004MYLJ43   CPTA   7.950000   8.016000   7.860000
# 1187908 2018-05-03  BBG004MYLJ43   CPTA   7.930000   7.930000   7.750000
# 1187910 2018-05-04  BBG004MYLJ43   CPTA   7.820000   7.854000   7.700000
# 1187912 2018-05-07  BBG004MYLJ43   CPTA   7.750000   7.790000   7.660000
# 1187914 2018-05-08  BBG004MYLJ43   CPTA   7.790000   7.990000   7.790000
# 1187916 2018-05-09  BBG004MYLJ43   CPTA   8.000000   8.050000   7.970000
# 1187918 2018-05-10  BBG004MYLJ43   CPTA   7.930000   8.100000   7.930000
# 1187920 2018-05-11  BBG004MYLJ43   CPTA   8.060000   8.290000   8.060000
# 1187922 2018-05-14  BBG004MYLJ43   CPTA   8.300000   8.448000   8.260000
# 1187924 2018-05-15  BBG004MYLJ43   CPTA   8.400000   8.430000   8.320000
# 1187926 2018-05-16  BBG004MYLJ43   CPTA   8.400000   8.470000   8.300000
# 1187928 2018-05-17  BBG004MYLJ43   CPTA   8.470000   8.590000   8.440000
# 1187930 2018-05-18  BBG004MYLJ43   CPTA   8.540000   8.550000   8.434000
# 1187932 2018-05-21  BBG004MYLJ43   CPTA   8.490000   8.490000   8.361000
# 1187934 2018-05-22  BBG004MYLJ43   CPTA   8.490000   8.490000   8.210000
#
#              close     volume
# 1185590  18.799999  2729500.0
# 1185592  19.150000   146300.0
# 1185594  19.049999   163800.0
# 1185596  19.200001    68400.0
# 1185598  18.950001    36800.0
# 1185600  18.719999    67400.0
# 1185602  18.250000   153300.0
# 1185604  17.950001    49900.0
# 1185606  18.309999    30300.0
# 1185608  18.280001    18200.0
# 1185610  18.549999    26500.0
# 1185612  18.500000    27100.0
# 1185614  18.400000    40000.0
# 1185616  18.520000    26600.0
# 1185618  18.209999    43500.0
# 1185620  18.059999    47000.0
# 1185622  18.780001    52600.0
# 1185624  18.629999   114700.0
# 1185626  19.209999   101600.0
# 1185628  19.110001    45500.0
# 1185630  19.250000    39500.0
# 1185632  19.110001    46200.0
# 1185634  19.240000    27000.0
# 1185636  19.360001    40600.0
# 1185638  19.600000    40800.0
# 1185640  19.150000    39600.0
# 1185642  18.850000    30300.0
# 1185644  19.000000     9200.0
# 1185646  19.010000    34400.0
# 1185648  19.010000    57000.0
# ...            ...        ...
# 1187876   7.810000    69200.0
# 1187878   7.830000    35500.0
# 1187880   7.830000    56800.0
# 1187882   7.970000    55400.0
# 1187884   8.110000    87200.0
# 1187886   7.980000    70700.0
# 1187888   8.050000    67400.0
# 1187890   7.920000    44800.0
# 1187892   7.950000    71700.0
# 1187894   7.980000    57800.0
# 1187896   7.950000    42200.0
# 1187898   7.950000    34900.0
# 1187900   7.980000    62200.0
# 1187902   7.980000    61300.0
# 1187904   7.950000    43700.0
# 1187906   7.920000    81600.0
# 1187908   7.850000    44100.0
# 1187910   7.790000    47800.0
# 1187912   7.690000   119100.0
# 1187914   7.990000   167700.0
# 1187916   7.980000    58200.0
# 1187918   8.070000    77800.0
# 1187920   8.280000   127800.0
# 1187922   8.420000    85900.0
# 1187924   8.400000    47300.0
# 1187926   8.450000    30800.0
# 1187928   8.530000    99800.0
# 1187930   8.440000    74800.0
# 1187932   8.490000    41700.0
# 1187934   8.300000    84600.0
#
# [1173 rows x 8 columns]

# %%
df[df.duplicated(subset=['date'])]
# Out:
# Empty DataFrame
# Columns: [date, entity_figi, ticker, open, high, low, close, volume]
# Index: []

# %%
len(ticker_figi[ticker_figi.entity_figi != 1])
# Out:
# 10

# %%
# Check the date gap
price_test = price.copy()
price_test = price_test.sort_values(['ticker', 'date']).reset_index(drop=True)
price_test['next_date'] = price_test.groupby('ticker')['date'].shift(-1)
price_test['date_gap'] = price_test.apply(lambda x:(x['next_date'] - x['date']).days, axis=1)

# %%
# Quick check to see if there are any date gaps bigger than 3 days 
price_test[(price_test['date_gap'].notnull()) & (price_test['date_gap'] > 3)].sort_values('date_gap', ascending=False).head()
# Out:
#               date   entity_figi ticker       open    high        low   close  \
# 2956102 2014-09-23    UNASSIGNED   KORZ  23.190001  23.410  23.139999  23.410
# 724651  2014-09-23    UNASSIGNED   BRZS  31.620001  33.090  30.250000  32.020
# 5249778 2016-03-10  BBG008G2LBZ4     UK  20.500000  20.500  20.500000  20.500
# 1974025 2014-02-03  BBG007FL7ZK4   FLOW   4.040000   4.040   4.040000   4.040
# 556000  2015-03-24  BBG000BM06Y7    BDI   0.001000   0.001   0.001000   0.001
#
#           volume  next_date  date_gap
# 2956102   3100.0 2016-11-14     783.0
# 724651   34500.0 2016-11-14     783.0
# 5249778      0.0 2017-10-26     595.0
# 1974025      0.0 2015-09-17     591.0
# 556000       0.0 2016-08-22     517.0

# %%
price_test[price_test.date_gap > 4].ticker.nunique()
# Out:
# 197

# %%
# After a check, we found that 197 tickers have date_gap > 4, so remove them
abnormal_ticker = list(price_test[price_test.date_gap > 4].ticker.unique())
normal_ticker_price = price_test[~price_test.ticker.isin(abnormal_ticker)]

# %%
# After remove the tickers have date-gap > 4, 4753 tickers remained
normal_ticker_price.ticker.nunique()
# Out:
# 4753

# %%
# But only 4743 tickers have date_gap == 1, so we need to check the 10 tickers left 
normal_ticker_price[normal_ticker_price.date_gap == 1].ticker.nunique()
# Out:
# 4743

# %%
# The 10 tickers do not have date_gap == 1 
# After the check we found that all these 10 tickers only have one record in total
set(normal_ticker_price.ticker.unique()) - set(normal_ticker_price[normal_ticker_price.date_gap == 1].ticker.unique())
# Out:
# {'CBG', 'DXM', 'GGP', 'GSIG', 'HCN', 'ITC', 'PCLN', 'SNI', 'STRN', 'TTF'}

# %%
price_test[price_test.ticker == 'CBG']
# Out:
#              date   entity_figi ticker       open  high        low      close  \
# 848675 2018-03-19  BBG000C043Q6    CBG  47.450001  47.5  46.779999  47.310001
#
#            volume next_date  date_gap
# 848675  1398603.0       NaT       NaN

# %%
price_test[price_test.ticker == 'DXM']
# Out:
#               date   entity_figi ticker          open          high  \
# 1551157 2018-04-25  BBG000BCKW07    DXM  10923.900391  10923.900391
#
#                   low         close  volume next_date  date_gap
# 1551157  10923.900391  10923.900391     0.0       NaT       NaN

# %%
price_test[price_test.ticker == 'GGP']
# Out:
#               date   entity_figi ticker       open       high    low  \
# 2153121 2018-08-27  BBG000BG3K58    GGP  22.030001  22.290001  21.83
#
#              close       volume next_date  date_gap
# 2153121  22.059999  181077630.0       NaT       NaN

# %%
price_test[price_test.ticker == 'GSIG']
# Out:
#               date entity_figi ticker       open       high        low  \
# 2268439 2018-05-22  UNASSIGNED   GSIG  64.150002  64.400002  62.400002
#
#              close    volume next_date  date_gap
# 2268439  62.549999  156200.0       NaT       NaN

# %%
price_test[price_test.ticker == 'HCN']
# Out:
#               date   entity_figi ticker       open       high        low  \
# 2339062 2018-02-27  BBG000BKY3S8    HCN  54.349998  54.709999  52.220001
#
#              close     volume next_date  date_gap
# 2339062  52.220001  3190327.0       NaT       NaN

# %%
price_test[price_test.ticker == 'ITC']
# Out:
#               date   entity_figi ticker  open  high  low  close  volume  \
# 2712999 2018-05-22  BBG000QDSVC0    ITC  4.12  4.12  4.1    4.1     0.0
#
#         next_date  date_gap
# 2712999       NaT       NaN

# %%
price_test[price_test.ticker == 'PCLN']
# Out:
#               date   entity_figi ticker         open         high  \
# 3934990 2018-02-26  BBG000BLC4L5   PCLN  1905.949951  1923.219971
#
#                  low        close    volume next_date  date_gap
# 3934990  1897.660034  1905.640015  570074.0       NaT       NaN

# %%
price_test[price_test.ticker == 'SNI']
# Out:
#               date   entity_figi ticker       open       high        low  \
# 4724848 2018-03-06  BBG000RQWCN5    SNI  90.099998  93.580002  89.769997
#
#              close      volume next_date  date_gap
# 4724848  90.040001  11132892.0       NaT       NaN

# %%
price_test[price_test.ticker == 'STRN']
# Out:
#               date   entity_figi ticker    open    high     low   close  \
# 4871240 2018-04-24  BBG000BR8N17   STRN  5000.0  5000.0  5000.0  5000.0
#
#          volume next_date  date_gap
# 4871240     0.0       NaT       NaN

# %%
price_test[price_test.ticker == 'TTF']
# Out:
#               date   entity_figi ticker    open    high     low   close  \
# 5159401 2018-04-25  BBG000BVRHP4    TTF  5300.0  5300.0  5300.0  5300.0
#
#          volume next_date  date_gap
# 5159401     0.0       NaT       NaN

# %%
# Remove the 10 tickers only have one record in total
useless_ticker = list(set(normal_ticker_price.ticker.unique()) - set(normal_ticker_price[normal_ticker_price.date_gap == 1].ticker.unique()))
remove_ticker = useless_ticker + abnormal_ticker
left_ticker_price = price[~price.ticker.isin(remove_ticker)]

# %% [markdown]
# ## Data Transformation

# %%
left_ticker_price = left_ticker_price.sort_values(["ticker", "date"]).reset_index(drop=True)
for n in range (1,6):
    for period in ["prior", "future"]:
        for col in ["open", "high", "low", "close", "volume"]:
            if period == "prior":
                left_ticker_price[f'{n}d_{period}_{col}'] = left_ticker_price.groupby('ticker')[col].shift(n)
            elif period == "future":
                left_ticker_price[f'{n}d_{period}_{col}'] = left_ticker_price.groupby('ticker')[col].shift(-n)

# %%
left_ticker_price.tail()
# Out:
#               date   entity_figi ticker   open   high    low  close    volume  \
# 5591938 2018-05-16  BBG009J96R40   ZYNE   9.47   9.53  9.070   9.40  154600.0
# 5591939 2018-05-17  BBG009J96R40   ZYNE   9.47   9.97  9.350   9.81  247900.0
# 5591940 2018-05-18  BBG009J96R40   ZYNE   9.88  10.47  9.870  10.28  285600.0
# 5591941 2018-05-21  BBG009J96R40   ZYNE  10.36  10.54  9.621   9.98  292200.0
# 5591942 2018-05-22  BBG009J96R40   ZYNE  10.06  10.64  9.901  10.34  261000.0
#
#          1d_prior_open  1d_prior_high  1d_prior_low  1d_prior_close  \
# 5591938           9.37           9.73         9.360            9.47
# 5591939           9.47           9.53         9.070            9.40
# 5591940           9.47           9.97         9.350            9.81
# 5591941           9.88          10.47         9.870           10.28
# 5591942          10.36          10.54         9.621            9.98
#
#          1d_prior_volume  1d_future_open  1d_future_high  1d_future_low  \
# 5591938         170500.0            9.47            9.97          9.350
# 5591939         154600.0            9.88           10.47          9.870
# 5591940         247900.0           10.36           10.54          9.621
# 5591941         285600.0           10.06           10.64          9.901
# 5591942         292200.0             NaN             NaN            NaN
#
#          1d_future_close  1d_future_volume  2d_prior_open  2d_prior_high  \
# 5591938             9.81          247900.0           9.22           9.54
# 5591939            10.28          285600.0           9.37           9.73
# 5591940             9.98          292200.0           9.47           9.53
# 5591941            10.34          261000.0           9.47           9.97
# 5591942              NaN               NaN           9.88          10.47
#
#          2d_prior_low  2d_prior_close  2d_prior_volume  2d_future_open  \
# 5591938          9.05            9.44         165900.0            9.88
# 5591939          9.36            9.47         170500.0           10.36
# 5591940          9.07            9.40         154600.0           10.06
# 5591941          9.35            9.81         247900.0             NaN
# 5591942          9.87           10.28         285600.0             NaN
#
#          2d_future_high  2d_future_low  2d_future_close  2d_future_volume  \
# 5591938           10.47          9.870            10.28          285600.0
# 5591939           10.54          9.621             9.98          292200.0
# 5591940           10.64          9.901            10.34          261000.0
# 5591941             NaN            NaN              NaN               NaN
# 5591942             NaN            NaN              NaN               NaN
#
#          3d_prior_open  3d_prior_high  3d_prior_low  3d_prior_close  \
# 5591938           8.77           9.24         8.751            9.23
# 5591939           9.22           9.54         9.050            9.44
# 5591940           9.37           9.73         9.360            9.47
# 5591941           9.47           9.53         9.070            9.40
# 5591942           9.47           9.97         9.350            9.81
#
#          3d_prior_volume  3d_future_open  3d_future_high  3d_future_low  \
# 5591938         206100.0           10.36           10.54          9.621
# 5591939         165900.0           10.06           10.64          9.901
# 5591940         170500.0             NaN             NaN            NaN
# 5591941         154600.0             NaN             NaN            NaN
# 5591942         247900.0             NaN             NaN            NaN
#
#          3d_future_close  3d_future_volume  4d_prior_open  4d_prior_high  \
# 5591938             9.98          292200.0           8.62           9.12
# 5591939            10.34          261000.0           8.77           9.24
# 5591940              NaN               NaN           9.22           9.54
# 5591941              NaN               NaN           9.37           9.73
# 5591942              NaN               NaN           9.47           9.53
#
#          4d_prior_low  4d_prior_close  4d_prior_volume  4d_future_open  \
# 5591938         8.620            8.75         281500.0           10.06
# 5591939         8.751            9.23         206100.0             NaN
# 5591940         9.050            9.44         165900.0             NaN
# 5591941         9.360            9.47         170500.0             NaN
# 5591942         9.070            9.40         154600.0             NaN
#
#          4d_future_high  4d_future_low  4d_future_close  4d_future_volume  \
# 5591938           10.64          9.901            10.34          261000.0
# 5591939             NaN            NaN              NaN               NaN
# 5591940             NaN            NaN              NaN               NaN
# 5591941             NaN            NaN              NaN               NaN
# 5591942             NaN            NaN              NaN               NaN
#
#          5d_prior_open  5d_prior_high  5d_prior_low  5d_prior_close  \
# 5591938           9.00           9.01         8.430            8.65
# 5591939           8.62           9.12         8.620            8.75
# 5591940           8.77           9.24         8.751            9.23
# 5591941           9.22           9.54         9.050            9.44
# 5591942           9.37           9.73         9.360            9.47
#
#          5d_prior_volume  5d_future_open  5d_future_high  5d_future_low  \
# 5591938         458600.0             NaN             NaN            NaN
# 5591939         281500.0             NaN             NaN            NaN
# 5591940         206100.0             NaN             NaN            NaN
# 5591941         165900.0             NaN             NaN            NaN
# 5591942         170500.0             NaN             NaN            NaN
#
#          5d_future_close  5d_future_volume
# 5591938              NaN               NaN
# 5591939              NaN               NaN
# 5591940              NaN               NaN
# 5591941              NaN               NaN
# 5591942              NaN               NaN

# %%
left_ticker_price.to_csv('us_equity_daily_price_201308_201908_transformed.csv', index=False)
